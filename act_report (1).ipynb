# %% [markdown]
# ## Report: act_report

# %% [markdown]
# Upon dissecting the data pertaining to dog ratings in WeRateDogs' tweets, we unearthed several intreging insights.
#
# WeRateDogs employs a distinctive canine rating system, consistently awarding ratings that transcend the scale of 10 out of 10. Throughout our analysis, a rating of 12 out of 10 emerged as the most frequently assigned, signifying the predilection for raising the evaluation beyond the normal range. With an average rating of 12.125, the analogy can be drawn to awarding a score of 121 out of 100 on an academic assignment.
#
# We also delved into the realm of frequently rated dog breeds, a representation of which is visualized in the chart below. The 'Unknown' category emerged as the most recurrent breed, a term which was assigned when the neural network fails to predict the breed based on the image. This occurrence could be attributed to the complicated nature of mixed breeds not falling into one category or the image's inadequacy for the neural network. Subsequently, Golden Retrievers and Labrador Retrievers secured the following two positions in terms of frequency.
#
# Leveraging the retweet information derived from the API, we examined the images that garnered the highest retweet count from viewers. In this context as well, the breeds with the highest retweet frequency comprised 'Unknown,' Golden Retrievers, and Labrador Retrievers. The rationale behind this trend is diverse, ranging from aesthetic preferences to the breeds' popularity as pets, ease of capturing appealing images, and beyond. The following are all of the top 10 of the breeds:
# 1.	Unknown
# 2.	Golden Retriever
# 3.	Labrador Retriever
# 4.	Pembroke
# 5.	Chihuahua
# 6.	Samoyed
# 7.	French Bulldog
# 8.	Cocker Spaniel
# 9.	Chow
# 10.	Pug

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('dog_breed_chart.png');

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432 at 0x7FC290A28A58>

# %%
Resources: https://saturncloud.io/blog/how-to-show-images-in-jupyter-notebook/
